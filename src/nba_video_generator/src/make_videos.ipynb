# %%
from nba_video_generator.beta_search import pipeline;
import time;
pipeline(
    [
       ("Wembanyama", "2026-06-05", "sas"),
       ("Harper", "2026-06-05", "sas"),
       ("Fox", "2026-06-05", "sas"),
    ],
    {"ffmpeg_path": r"C:\Users\ronen\Documents\Projects\nba_video_generator\src\nba_video_generator\ffmpeg-2025-10-21-git-535d4047d3-essentials_build\bin\ffmpeg.exe"}
)

# %%
from nba_video_generator.beta_search import pipeline;
import time;
pipeline(
    [
        ("Leonard", "2019-06-07", "tor"),
        ("Curry", "2018-06-08", "gsw"),
        ("Doncic", "2024-06-09", "dal"),
        ("Curry", "2022-06-10", "gsw"),
    ],
    {"ffmpeg_path": r"C:\Users\ronen\Documents\Projects\nba_video_generator\src\nba_video_generator\ffmpeg-2025-10-21-git-535d4047d3-essentials_build\bin\ffmpeg.exe"}
)

# %%
from nba_video_generator.beta_search import pipeline;
import time;
pipeline(
    [
        ("Bridges", "2026-05-04", "2026-05-10", "nyk"),
        ("Mitchell", "2026-05-05", "2026-05-11", "okc"),
        ("Mobley", "2026-05-05", "2026-05-17", "cle"),
        ("Castle", "2026-05-04", "2026-05-15", "sas"),
    ],
    {"ffmpeg_path": r"C:\Users\ronen\Documents\Projects\nba_video_generator\src\nba_video_generator\ffmpeg-2025-10-21-git-535d4047d3-essentials_build\bin\ffmpeg.exe"}
)

# %%
# DOES NOT WORK WITH FREE THROWS.

from nba_video_generator.search import pipeline

player_params = {
    "date_start": "2026-05-19",
    "date_end": "2026-05-25",
    "FGM": False,
    "FGA": True,
    "ThreePM": False,
    "ThreePA": False,
    "OREB": False,
    "DREB": False,
    "REB": True,
    "AST": True,
    "STL": True,
    "BLK": True,
    "TO": True,
    "PF": True,
    "include_ft": True
}

video_params = {
    "fps": 30,
    "preset": 'ultrafast',
    "segment": 'Play',
    "include_caption": True,
    "ffmpeg_path": r"C:\Users\ronen\Documents\Projects\nba_video_generator\src\nba_video_generator\ffmpeg-2025-10-21-git-535d4047d3-essentials_build\bin\ffmpeg.exe"
}

name_team_base = [
    ("Brunson", "nyk", "jbrunson"),
]

pipeline(player_params, video_params, name_team_base)
