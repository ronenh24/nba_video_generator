# %%
from nba_video_generator.beta_search import pipeline;
import time;
pipeline(
    [
        ("Gilgeous-Alexander", "2026-05-28", "okc"),
    ],
    {"ffmpeg_path": r"C:\Users\ronen\Documents\Projects\nba_video_generator\src\nba_video_generator\ffmpeg-2025-10-21-git-535d4047d3-essentials_build\bin\ffmpeg.exe"}
)

# %%
from nba_video_generator.beta_search import pipeline;import time;
time.sleep(1200);pipeline([("Harper", "2026-05-28", "sas"),("Wembanyama", "2026-05-28", "sas"),("Castle", "2026-05-28", "sas"),],{"ffmpeg_path": r"C:\Users\ronen\Documents\Projects\nba_video_generator\src\nba_video_generator\ffmpeg-2025-10-21-git-535d4047d3-essentials_build\bin\ffmpeg.exe"})

# %%
from nba_video_generator.beta_search import pipeline
pipeline(
    [
        ("Fleming", "2025-10-22", "2026-04-27", "phx"),
    ],
    {"ffmpeg_path": r"C:\Users\ronen\Documents\Projects\nba_video_generator\src\nba_video_generator\ffmpeg-2025-10-21-git-535d4047d3-essentials_build\bin\ffmpeg.exe"}
)

# %%
# DOES NOT WORK WITH FREE THROWS.

from nba_video_generator.search import pipeline

player_params = {
    "date_start": "2026-05-19",
    "date_end": "2026-05-25",
    "FGM": False,
    "FGA": True,
    "ThreePM": False,
    "ThreePA": False,
    "OREB": False,
    "DREB": False,
    "REB": True,
    "AST": True,
    "STL": True,
    "BLK": True,
    "TO": True,
    "PF": True,
    "include_ft": True
}

video_params = {
    "fps": 30,
    "preset": 'ultrafast',
    "segment": 'Play',
    "include_caption": True,
    "ffmpeg_path": r"C:\Users\ronen\Documents\Projects\nba_video_generator\src\nba_video_generator\ffmpeg-2025-10-21-git-535d4047d3-essentials_build\bin\ffmpeg.exe"
}

name_team_base = [
    ("Brunson", "nyk", "jbrunson"),
]

pipeline(player_params, video_params, name_team_base)
